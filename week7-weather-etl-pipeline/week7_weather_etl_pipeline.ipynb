# %%
import requests
import pandas as pd
from datetime import datetime

# %%
API_KEY = "your_api_key_here"
cities = ["Lagos", "Abuja", "Port Harcourt"]

# %%
city = "Lagos"
url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}&units=metric"

response = requests.get(url)
print(response.status_code)
print(response.json())
# Out:
# 200
# {'coord': {'lon': 3.75, 'lat': 6.5833}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 25.18, 'feels_like': 26.05, 'temp_min': 25.18, 'temp_max': 25.18, 'pressure': 1014, 'humidity': 88, 'sea_level': 1014, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 4.32, 'deg': 242, 'gust': 9.09}, 'rain': {'1h': 0.48}, 'clouds': {'all': 100}, 'dt': 1784220963, 'sys': {'country': 'NG', 'sunrise': 1784180213, 'sunset': 1784225087}, 'timezone': 3600, 'id': 2332453, 'name': 'Lagos', 'cod': 200}

# %%
weather_data = []

for city in cities:
    url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}&units=metric"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        weather_data.append({
            "City": data["name"],
            "Temperature (°C)": data["main"]["temp"],
            "Feels Like (°C)": data["main"]["feels_like"],
            "Humidity (%)": data["main"]["humidity"],
            "Weather Condition": data["weather"][0]["main"],
            "Description": data["weather"][0]["description"],
            "Wind Speed (m/s)": data["wind"]["speed"],
            "Date/Time Retrieved": datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        })
    else:
        print(f"Failed to get data for {city}: {response.status_code}")

print(weather_data)
# Out:
# [{'City': 'Lagos', 'Temperature (°C)': 25.18, 'Feels Like (°C)': 26.05, 'Humidity (%)': 88, 'Weather Condition': 'Rain', 'Description': 'light rain', 'Wind Speed (m/s)': 4.32, 'Date/Time Retrieved': '2026-07-16 16:58:07'}, {'City': 'Abuja', 'Temperature (°C)': 24.48, 'Feels Like (°C)': 25.2, 'Humidity (%)': 85, 'Weather Condition': 'Clouds', 'Description': 'overcast clouds', 'Wind Speed (m/s)': 1.51, 'Date/Time Retrieved': '2026-07-16 16:58:07'}, {'City': 'Port Harcourt', 'Temperature (°C)': 22.6, 'Feels Like (°C)': 23.42, 'Humidity (%)': 96, 'Weather Condition': 'Rain', 'Description': 'moderate rain', 'Wind Speed (m/s)': 3.01, 'Date/Time Retrieved': '2026-07-16 16:58:08'}]

# %%
df = pd.DataFrame(weather_data)
df
# Out:
#             City  Temperature (°C)  Feels Like (°C)  Humidity (%)  \
# 0          Lagos             25.18            26.05            88
# 1          Abuja             24.48            25.20            85
# 2  Port Harcourt             22.60            23.42            96
#
#   Weather Condition      Description  Wind Speed (m/s)  Date/Time Retrieved
# 0              Rain       light rain              4.32  2026-07-16 16:58:07
# 1            Clouds  overcast clouds              1.51  2026-07-16 16:58:07
# 2              Rain    moderate rain              3.01  2026-07-16 16:58:08

# %%
df.dtypes
# Out:
# City                    object
# Temperature (°C)       float64
# Feels Like (°C)        float64
# Humidity (%)             int64
# Weather Condition       object
# Description             object
# Wind Speed (m/s)       float64
# Date/Time Retrieved     object
# dtype: object

# %%
df["Date/Time Retrieved"] = pd.to_datetime(df["Date/Time Retrieved"])
df.dtypes
# Out:
# City                           object
# Temperature (°C)              float64
# Feels Like (°C)               float64
# Humidity (%)                    int64
# Weather Condition              object
# Description                    object
# Wind Speed (m/s)              float64
# Date/Time Retrieved    datetime64[ns]
# dtype: object

# %%
df.to_csv("weather_data.csv", index=False)
print("Saved successfully!")
# Out:
# Saved successfully!

# %%
from google.colab import files
files.download("weather_data.csv")

# %%
# City with highest temperature
hottest = df.loc[df["Temperature (°C)"].idxmax()]
print(f"Hottest city: {hottest['City']} at {hottest['Temperature (°C)']}°C")

# City with highest humidity
most_humid = df.loc[df["Humidity (%)"].idxmax()]
print(f"Most humid city: {most_humid['City']} at {most_humid['Humidity (%)']}%")

# City with highest wind speed
windiest = df.loc[df["Wind Speed (m/s)"].idxmax()]
print(f"Windiest city: {windiest['City']} at {windiest['Wind Speed (m/s)']} m/s")

# Weather condition comparison
print("\nWeather conditions across cities:")
print(df[["City", "Weather Condition", "Description"]])
# Out:
# Hottest city: Lagos at 25.18°C
# Most humid city: Port Harcourt at 96%
# Windiest city: Lagos at 4.32 m/s
#
# Weather conditions across cities:
#             City Weather Condition      Description
# 0          Lagos              Rain       light rain
# 1          Abuja            Clouds  overcast clouds
# 2  Port Harcourt              Rain    moderate rain
